# %%
#1.What error will occur in the following code, and how do you fix it?
def say_hello(name)
    print("Hello," +name)

# %%
#Ans: put colon in the function
def say_hello(name):
    print("Hello," +name)

# %%
#2.What error will occur in the following code, and how do you fix it?
age = 25
print("I am " + age + " years old")

# %%
#Ans:
age = "25"
print("I am " + age + " years old")
# Out:
# I am 25 years old

# %%
#3What is the issue with the following code?
def greet():
    message = "Hello"
print(message)
# Out:
# Object `code` not found.

# %%
#Ans:function does not need in this place
#def greet(message):
message = "Hello"
print(message)
# Out:
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5))

# %%
#Ans:requires two argument

def add(a, b):
    return a + b

print(add(5,4))
# Out:
# 9

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False

# %%
#Ans:function calling missing
def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False
is_even(7)
# Out:
# True

# %%
#6.What happens when you run this code?

num = int("10")
print(num)
#
# Out:
# 10

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]

#sort gives the values in ASC or DSC.
#reverse gives the values in reverse order

# %%
#Ans:
numbers = [1, 2, 3, 4]
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?

numbers = [1, 2, 3]
numbers = numbers.append(4)
print(numbers)
# Out:
# None

# %%
#Ans:
numbers = [1, 2, 3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?

#Ans:
#count = 10

def increment(count):
    count += 1
    print(count)

increment(10)
# Out:
# 11

# %%
#Ans:
count = 10
#def increment():
    count += 1
    print(count)

#increment()
# Out:
# 11

# %%
#10.What error will occur in the following code?
#Ans
text = "Python"
print(text[5])
#index range is 0 to 5
# Out:
# n
